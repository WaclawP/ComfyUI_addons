# %%
#@title DeFooocus
#@markdown **Launch the interface DeFocus (Fooocus fork)** | You need to connect with T4/A100/V100
#@markdown ****
#@markdown *Attention!* When working in the interface with the FaceSwap and CPDS controlnet, crashes are possible; it is also recommended to work in *Extreme speed* mode for additional stability. When working with the ImagePrompt and PyraCanny controls, 85% of the work will be stable.
#@markdown ****

print("[DeFooocus] Preparing ...")

theme = "dark" #@param ["dark", "light"]
preset = "deafult" #@param ["deafult", "realistic", "anime", "lcm", "sai", "turbo", "lighting", "hypersd", "playground_v2.5", "dpo", "spo", "sd1.5"]
advenced_args = "--share --attention-split --always-high-vram --disable-offload-from-vram --all-in-fp16" #@param {type: "string"}

if preset != "deafult":
  args = f"{advenced_args} --theme {theme} --preset {preset}"
else:
  args = f"{advenced_args} --theme {theme}"

# !pip install -q pygit2==1.12.2
# %cd /workspace
# !git clone https://github.com/ehristoforu/DeFooocus.git
# %cd /workspace/DeFooocus
# !pip install -q -r requirements_versions.txt

print("[DeFooocus] Starting ...")
# !python entry_with_update.py $args
# Out:
# [DeFooocus] Preparing ...
# /workspace
# Cloning into 'DeFooocus'...
# remote: Enumerating objects: 6989, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 6989 (delta 69), reused 116 (delta 68), pack-reused 6867
# Receiving objects: 100% (6989/6989), 47.28 MiB | 59.25 MiB/s, done.
# Resolving deltas: 100% (3831/3831), done.
# /workspace/DeFooocus
# [DeFooocus] Starting ...
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--attention-split', '--always-high-vram', '--disable-offload-from-vram', '--all-in-fp16', '--theme', 'dark']
# Python 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]
# Fooocus version: 0.2
# Version mismatch for scipy: Installed version 1.11.2 does not meet requirement scipy==1.9.3
# Installing requirements
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /workspace/DeFooocus/models/vae_approx/xlvaeapp.pth
#
# 100%|████████████████████████████████████████| 209k/209k [00:00<00:00, 10.7MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /workspace/DeFooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100%|████████████████████████████████████████| 209k/209k [00:00<00:00, 10.9MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xl-to-v1_interposer-v3.1.safetensors" to /workspace/DeFooocus/models/vae_approx/xl-to-v1_interposer-v3.1.safetensors
#
# 100%|███████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 112MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /workspace/DeFooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100%|█████████████████████████████████████████| 335M/335M [00:01<00:00, 296MB/s]
# Downloading: "https://huggingface.co/fluently/Fluently-XL-v4/resolve/main/FluentlyXL-v4.safetensors" to /workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors
#
# 100%|███████████████████████████████████████| 6.62G/6.62G [00:19<00:00, 356MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /workspace/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100%|███████████████████████████████████████| 47.3M/47.3M [00:00<00:00, 266MB/s]
# Total VRAM 24248 MB, total RAM 257565 MB
# xformers version: 0.0.21
# Forcing FP16.
# Set vram state to: HIGH_VRAM
# Device: cuda:0 NVIDIA RTX A5000 : native
# VAE dtype: torch.bfloat16
# Using xformers cross attention
# Refiner unloaded.
# model_type EPS
# UNet ADM Dimension 2816
# Using xformers attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using xformers attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_g.transformer.text_model.embeddings.position_ids', 'cond_stage_model.clip_l.text_projection'}
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/workspace/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.41 seconds
# Started worker with PID 739
# 'NoneType' object has no attribute 'local_url'
# themes/theme_schema@0.0.1.json: 100%|██████| 13.7k/13.7k [00:00<00:00, 79.2MB/s]
# Running on local URL:  http://127.0.0.1:7865
# IMPORTANT: You are using gradio version 3.41.2, however version 4
...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/sdxl_lcm_lora.safetensors" to /workspace/DeFooocus/models/loras/sdxl_lcm_lora.safetensors
#
# 100%|█████████████████████████████████████████| 376M/376M [00:01<00:00, 343MB/s]
# [Parameters] Adaptive CFG = 1.0
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] CFG = 1.0
# [Parameters] Seed = 8372893088938675311
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0], ('sdxl_lcm_lora.safetensors', 1.0)] for model [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/workspace/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# Loaded LoRA [/workspace/DeFooocus/models/loras/sdxl_lcm_lora.safetensors] for UNet [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 1.0.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 0.84 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] in cat space on t-shirt, bright beautiful, intricate, elegant, highly detailed, symmetry, great composition, dramatic light, sharp focus, cinematic, artistic, fine detail, expressive, open dynamic color, elaborate, iconic, polished, complex, amazing deep colors, cute, brilliant, colorful, coherent, awesome, shiny, vivid, wonderful, epic, illuminated, very
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] in cat space on t-shirt, bright glowing, extremely detailed, cinematic, complex, highly color, dramatic, intricate, elegant, sharp focus, romantic, artistic, innocent, enchanted, magic, mystical, professional, stunning, amazing, winning, awesome, gorgeous, emotional, beautiful, shiny, pretty, attractive, surreal background, best, epic, fine, very coherent
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] in cat space on t-shirt, bright glowing, professional, extremely detailed, beautiful, intricate, innocent, magical, enchanted, magic, dramatic, sharp focus, epic, stunning, highly advanced, amazing composition, cinematic, complex, cool background, rich vivid colors, inspired, new, color, light, famous, awesome, symmetry, illuminated, best, winning, clear
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] in cat space on t-shirt, full decorated, expressive, beautiful, intricate, elegant, highly detailed, symmetry, illuminated, sharp focus, fair balanced composition, clear background, inspired, extremely detail, cinematic, artistic, fine frank, rich deep colors, perfect light, inspiring, novel, epic, stunning, gorgeous, fascinating, creative, breathtaking, thoughtful, lucid
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 7.30 seconds
# Using lcm scheduler.
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970144629478455, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# unload clone 2
# [Fooocus Model Management] Moving model(s) has taken 0.45 seconds
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  6.35it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.57 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  6.97it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.99 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.00it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.00 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  6.98it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.96 seconds
# Total time: 15.85 seconds
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] CFG = 1.0
# [Parameters] Seed = 1554314712617252759
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] caraibien beach background, vibrant colors, dynamic dramatic cinematic light, detailed, warm color, built, intricate, epic composition, stunning, highly detail, professional still, full focus, beautiful, creative, positive, attractive, unique, cute, best, pure, perfect, fine, futuristic, cool, awesome, elegant, surreal, artistic, sharp, magic, pretty
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] caraibien beach background, intricate, elegant, highly detailed, symmetry, sharp focus, beautiful light, clear professional, cinematic, directed, ambient, full color, epic, best, fair, crisp, artistic, striking, emotional, gorgeous, pretty, fine detail, creative, positive, attractive, cute, enhanced, colorful, vibrant, iconic, determined, loving
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] caraibien beach background, intricate, elegant, highly detailed, vibrant, symmetry, full color, sharp focus, epic composition, joyful, magical atmosphere, cinematic, directed, vivid, beautiful, aesthetic, very inspirational, original, fine detail, professional, winning, decorated, complex, new, best, creative, positive, unique, attractive, cute, confident, inspired
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] caraibien beach background, light, strong dramatic cinematic color, perfect intricate, elegant, sharp focus, extremely detailed, professional composition, innocent, fantastic, aesthetic, very inspirational, cute, fine detail, full bright colors, amazing, gorgeous, symmetry, pretty, attractive, creative, positive, joyful, unique, beautiful, moving, pure, rational, thought, pristine
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.69 seconds
# Using lcm scheduler.
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# unload clone 3
# [Fooocus Model Management] Moving model(s) has taken 0.39 seconds
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.27it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.29 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.24it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.89 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.24it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.90 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.21it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.87 seconds
# Total time: 10.71 seconds
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] CFG = 1.0
# [Parameters] Seed = 4244021463862352758
# [Fooocus] Downloading upscale models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_upscaler_s409985e5.bin" to /workspace/DeFooocus/models/upscale_models/fooocus_upscaler_s409985e5.bin
#
# 100%|███████████████████████████████████████| 32.1M/32.1M [00:00<00:00, 236MB/s]
# [Fooocus] Downloading inpainter ...
# Downloading: "https://huggingface.co/lllyasviel/fooocus_inpaint/resolve/main/fooocus_inpaint_head.pth" to /workspace/DeFooocus/models/inpaint/fooocus_inpaint_head.pth
#
# 100%|██████████████████████████████████████| 51.4k/51.4k [00:00<00:00, 7.62MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fooocus_inpaint/resolve/main/inpaint_v26.fooocus.patch" to /workspace/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch
#
# 100%|███████████████████████████████████████| 1.23G/1.23G [00:03<00:00, 357MB/s]
# [Inpaint] Current inpaint model is /workspace/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0], ('sdxl_lcm_lora.safetensors', 1.0), ('/workspace/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch', 1.0)] for model [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/workspace/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# Loaded LoRA [/workspace/DeFooocus/models/loras/sdxl_lcm_lora.safetensors] for UNet [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 1.0.
# Loaded LoRA [/workspace/DeFooocus/models/inpaint/inpaint_v26.fooocus.patch] for UNet [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 960 keys at weight 1.0.
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0], ('sdxl_lcm_lora.safetensors', 1.0)] for model [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/workspace/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# Loaded LoRA [/workspace/DeFooocus/models/loras/sdxl_lcm_lora.safetensors] for UNet [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 1.0.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.13 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] cat head, intricate, elegant, glowing light, highly detailed, extremely complex, sharp focus, cinematic, magical atmosphere, unique, fine detail, perfect, colorful, beautiful, pure color, inspired very strong, original composition, ambient background, professional, stunning, enhanced, best, creative, positive, wonderful, cute, innocent, symmetry, flawless, pretty, artistic, confident
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] cat head, intricate, elegant, highly detailed, symmetry, great composition, sharp focus, cinematic light, crisp detail, inspired, rich bright colors, open background, professional, extremely inspirational, beautiful, cute, depicted, deep clear emotional, shiny, glowing, lucid, thought winning, perfect, rational, epic, artistic, complex, color, cool, best, romantic
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] cat head, deep focus, intricate, elegant, highly detailed, full perfect, sharp focused, beautiful, majestic, innocent, thought original, fine classic, colorful, inspiring, dynamic, shiny, attractive, pretty, inspired, vivid, color, light, winning, futuristic, magic, fashionable, professional, determined, extremely, illuminated, singular, handsome, amazing, awesome
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] cat head, intricate, elegant, highly detailed, symmetry, great composition, sharp focus, cinematic, fine detail, inspired very coherent colors, ambient light, dynamic background, professional, stunning, cute, best, creative, positive, unique, attractive, beautiful, atmosphere, new, friendly, imagined, perfect, colorful, epic, artistic, focused, shiny, optimistic, precious
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (175, 181, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# [Fooocus] VAE encoding ...
# Final resolution is (541, 1277), latent is (1024, 1024).
# [Parameters] Denoising Strength = 1
# [Parameters] Initial Latent shape: Image Space (1024, 1024)
# Preparation time: 16.67 seconds
# Using lcm scheduler.
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# unload clone 3
# [Fooocus Model Management] Moving model(s) has taken 8.49 seconds
#  50%|██████████████████████▌                      | 4/8 [00:00<00:00,  5.12it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.40 seconds
# Refiner Swapped
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  4.41it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 10.83 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 9.40 seconds
#  50%|██████████████████████▌                      | 4/8 [00:00<00:00,  6.86it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.40 seconds
# Refiner Swapped
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  5.22it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 11.44 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 9.15 seconds
#  50%|██████████████████████▌                      | 4/8 [00:00<00:00,  6.51it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.41 seconds
# Refiner Swapped
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  5.03it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 11.27 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 8.98 seconds
#  50%|██████████████████████▌                      | 4/8 [00:00<00:00,  6.39it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.40 seconds
# Refiner Swapped
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  5.11it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 11.08 seconds
# Total time: 61.31 seconds
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] CFG = 1.0
# [Parameters] Seed = 4336492683971293898
# [Fooocus] Downloading control models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/clip_vision_vit_h.safetensors" to /workspace/DeFooocus/models/clip_vision/clip_vision_vit_h.safetensors
#
# 100%|███████████████████████████████████████| 1.84G/1.84G [00:05<00:00, 361MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_ip_negative.safetensors" to /workspace/DeFooocus/models/controlnet/fooocus_ip_negative.safetensors
#
# 100%|██████████████████████████████████████| 64.1k/64.1k [00:00<00:00, 8.28MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/ip-adapter-plus_sdxl_vit-h.bin" to /workspace/DeFooocus/models/controlnet/ip-adapter-plus_sdxl_vit-h.bin
#
# 100%|█████████████████████████████████████████| 967M/967M [00:02<00:00, 356MB/s]
# [Fooocus] Loading control models ...
# extra clip vision: ['vision_model.embeddings.position_ids']
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0], ('sdxl_lcm_lora.safetensors', 1.0)] for model [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors].
# Loaded LoRA [/workspace/DeFooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 0.1.
# Loaded LoRA [/workspace/DeFooocus/models/loras/sdxl_lcm_lora.safetensors] for UNet [/workspace/DeFooocus/models/checkpoints/FluentlyXL-v4.safetensors] with 788 keys at weight 1.0.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 0.83 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] caraibien beach background, fine detail, intricate, elegant, dynamic, radiant colors, cinematic, highly detailed, sharp focus, divine holy light, professional composition, dramatic ambient, expressive, sublime, thought, extremely beautiful, stunning, symmetry, perfect, composed, colorful, illuminated, deep vibrant color, best, full, majestic, coherent, amazing, pure, wonderful
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] caraibien beach background, light, strong, crisp, extremely detailed, glowing, beautiful, intricate, elegant, sharp focus, stunning composition, cinematic, highly detail,, gorgeous, structured, full color, inspired, still, professional, thoughtful, passionate, colorful, artistic, winning, new, creative, attractive, loving, pretty, confident, cute, best
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] caraibien beach background, light, gorgeous, intricate, elegant, sharp focus, cinematic, highly detailed, clear, attractive, scientific, surreal, dramatic ambient, professional, artistic, stunning, magical, romantic, striking, pretty, cute, perfect, coherent, creative, thoughtful, positive, awesome, enhanced, colorful, best, neat, emotional, beautiful, focused
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] caraibien beach background, colorful, light, strong, crisp, extremely detailed, beautiful, intricate, innocent, magical, sharp focus, highly decorated, romantic, symmetry, brave, elegant, complex, iconic, fine detail, ambient, epic composition, pristine, cinematic, professional, thought, best, quality, dramatic, futuristic, stunning, glowing, rich, hopeful
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Image processing ...
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# Requested to load Resampler
# Loading 1 new model
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 25.84 seconds
# Using lcm scheduler.
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# unload clone 6
# [Fooocus Model Management] Moving model(s) has taken 0.66 seconds
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  5.71it/s]
# [Fooocus Model Management] Moving model(s) has taken 0.56 seconds
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 3.42 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  5.71it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.23 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  5.72it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.23 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  5.67it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.22 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 35.98 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] CFG = 1.0
# [Parameters] Seed = 5783483752423068079
# [Fooocus] Downloading control models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/control-lora-canny-rank128.safetensors" to /workspace/DeFooocus/models/controlnet/control-lora-canny-rank128.safetensors
#
# 100%|█████████████████████████████████████████| 377M/377M [00:01<00:00, 384MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] caraibien beach background, light, beautiful, intricate, elegant, sharp focus, cinematic, highly detailed, clear quality, surreal, dramatic, still, full color, epic composition, cool dynamic, glowing, professional, inspiring, confident, unique, attractive, artistic, exciting, creative, passionate, glorious, gorgeous, awesome, flowing, vibrant, perfect, coherent
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] caraibien beach background, vibrant color, light, clear focus, cinematic, highly detailed, intricate, elegant, complex, beautiful, stunning, modern, romantic, sharp, professional, winning, attractive, creative, expressive, perfect, pretty, cute, best, dramatic, lush, illuminated, stylish, cool, lovely, smart, fabulous, inspiring, wonderful, charming
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] caraibien beach background, intricate, elegant, highly detailed, lush, sharp focus, dramatic light, beautiful, enhanced quality, dynamic, cinematic, rich aesthetic, joyful, vibrant colors, open atmosphere, iconic, fine detail, full color, epic composition, creative, positive, unique, perfect, balanced, calm, loving, generous, pure, focused, winning
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] caraibien beach background, light, strong, crisp, detailed, artistic, romantic, vibrant, intricate, beautiful, epic composition, cinematic, highly saturated colors, striking, attractive, elegant, brave, futuristic, full color, best, modern, contemporary, sleek, cute, glowing, pretty, fine detail, inspired, amazing, symmetry, awarded, perfect, awesome
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Image processing ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 4.46 seconds
# Using lcm scheduler.
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# unload clone 6
# [Fooocus Model Management] Moving model(s) has taken 0.40 seconds
# 100%|█████████████████████████████████████████████| 8/8 [00:02<00:00,  3.98it/s]
# [Fooocus Model Management] Moving model(s) has taken 0.47 seconds
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 3.95 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  4.27it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.84 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  4.25it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.81 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  4.27it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.79 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 16.88 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.25 seconds
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] CFG = 1.0
# [Parameters] Seed = 2686347634073088587
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] caraibien beach background, full color, cinematic, stunning, highly detailed, formal, serious, determined, elegant, professional, light, dramatic ambient, great composition, focus, beautiful, symmetry, clear, aesthetic, very inspirational, colorful, open, positive, cheerful, unique, cute, creative, artistic, awesome, best, joyful, pretty, inspired, iconic
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] caraibien beach background, vibrant color, light, clear focus, highly detailed, cinematic, complex, elegant, confident, rich deep colors, romantic, magical, scenic, thought, ambient, pristine, magic, sharp, expressive, iconic, fine, symmetry, intricate, brilliant, colorful, awesome, full detail, elaborate, amazing composition, professional, winning, striking
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] caraibien beach background, vibrant colors, light, strong crisp quality, intricate, elegant, confident, highly detailed, formal, professional, cinematic, expressive, color, beautiful, dramatic, thought, best, sharp focus, fair, clear, quiet, aesthetic, attractive, pretty, innocent, imagined, epic, iconic, artistic, thoughtful, awesome, cute, perfect
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] caraibien beach background, cinematic, beautiful composition, intricate, elegant, sharp focus, ambient light, highly detailed, dynamic, radiant, amazing, full color, inspired, rich deep colors, new fine detail, great symmetry, clear, crisp, artistic, pure, hopeful, creative, positive, unique, attractive, cute, best, iconic, handsome, sublime
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Image processing ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.66 seconds
# Using lcm scheduler.
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# unload clone 6
# [Fooocus Model Management] Moving model(s) has taken 0.39 seconds
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  4.08it/s]
# [Fooocus Model Management] Moving model(s) has taken 0.45 seconds
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 3.77 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:02<00:00,  4.00it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 3.00 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:02<00:00,  3.99it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.99 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.43672478199005127, sigma_max = 14.614640235900879
# 100%|█████████████████████████████████████████████| 8/8 [00:02<00:00,  3.58it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 3.21 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 15.67 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] CFG = 1.0
# [Parameters] Seed = 6264724719124553734
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] caraibien beach background, swimsuit with cutouts, full colorful, expressive, sharp focus, intricate, elegant, highly detailed, cinematic, still, dynamic light, directed, color, rich deep colors, open complex scenic excellent composition, dramatic ambient glowing, very inspirational, stunning, inspired, pretty, attractive, illustrious, fine detail, creative, awesome, perfect
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion
seconds
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] CFG = 1.0
# [Parameters] Seed = 4053889200906550657
# [Fooocus] Downloading upscale models ...
# [Inpaint] Parameterized inpaint is disabled.
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] detailed young woman, intricate, elegant, glowing, highly detailed, dynamic, sharp focus, dramatic, cinematic, fine composition, joyful, beautiful, stunning, deep colors, enhanced light, amazing, full color, surreal background, inspired, rich vivid colorful, epic, great still, scenic, ambient, thought, perfect, thoughtful, professional, atmosphere, best, sunny
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] detailed young woman, intricate, elegant, highly detailed, sharp focus, candid, beautiful, scenic, thought, dramatic, ambient, glowing, rich deep colors, winning, perfect, colorful, epic, stunning, great composition, cinematic, light, symmetry, best, fair, clear, aesthetic, very inspirational, professional, artistic, passionate, color, iconic, fine
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] detailed young woman, intricate, elegant, highly detailed, sharp focus, candid, open, transparent, divine, shiny, glowing, striking, beautiful, symmetry, fine detail, full color, epic light, cinematic, dramatic atmosphere, new classic, creative, artistic, surreal,, calm, healing, colorful, illuminated, translucent, very coherent, cute, pretty, pure
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] detailed young woman, bright colors, striking, elegant, highly detailed, intricate, innocent, fine detail, light, inspired, pretty, confident, background, cinematic, glossy, vibrant, designed, deep focus, epic, great composition, dynamic illumination, beautiful, symmetry, perfect, full color, clear, coherent, fantastic, cute, amazing, creative, artistic, illuminated
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (896, 1021, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# [Fooocus] VAE encoding ...
# Final resolution is (896, 1152), latent is (960, 1088).
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 120, 136])
# Preparation time: 8.25 seconds
# Using lcm scheduler.
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# Requested to load SDXL
# Loading 1 new model
# unload clone 3
# [Fooocus Model Management] Moving model(s) has taken 0.39 seconds
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  6.36it/s]
# [Fooocus Model Management] Moving model(s) has taken 0.17 seconds
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.74 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.00it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.05 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  6.98it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.06 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  6.92it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.05 seconds
# Total time: 17.19 seconds
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] CFG = 1.0
# [Parameters] Seed = 8541163765525618069
# [Fooocus] Downloading upscale models ...
# [Inpaint] Parameterized inpaint is disabled.
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] detailed young woman, intricate, elegant, highly detailed, very inspired, glowing light, sharp focus, epic composition, joyful, professional atmosphere, dynamic dramatic cinematic perfect, fine detail, real flaming background, colorful, surreal, beautiful, pure color, illuminated, determined, radiant, extremely, focused, passionate, elite, incredible, artistic, smart, shiny, attractive, fancy
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] detailed young woman, intricate, elegant, highly detailed, flowing, sharp focus, dramatic, dynamic, full color, cinematic, worthy, vibrant, inspired, generous, thought, very inspirational, colorful, illuminated, glowing, amazing, epic, artistic, inspiring, beautiful, symmetry, cheerful, pretty, clear, perfect, background, relaxed, radiant, magical, iconic
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] detailed young woman, intricate, elegant, highly detailed, cinematic, extremely relaxed, fantastic composition, beautiful full novel, stunning, inspiring, thought, epic, crisp, sharp focus, amazing, gorgeous, elaborate, very inspirational, brilliant, awesome, radiant, coherent, incredible detail, bright color, enhanced, winning, pretty, smart, artistic, creative, passionate, marvelous
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] detailed young woman, intricate, elegant, highly detailed, wonderful colors, glowing, sharp focus, winning bright dramatic cinematic composition, very inspirational, cute, fine detail, full color, beautiful, attractive, pretty, delicate, confident, passionate, creative, cheerful, loving, complex, artistic, cool, vibrant, iconic, colorful, coherent, radiant, light, clear
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE Inpaint encoding ...
# [Fooocus] VAE encoding ...
# Final resolution is (896, 1152), latent is (896, 1024).
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 112, 128])
# Preparation time: 2.85 seconds
# Using lcm scheduler.
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# Requested to load SDXL
# Loading 1 new model
# unload clone 3
# [Fooocus Model Management] Moving model(s) has taken 0.38 seconds
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.15it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.31 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.71it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.84 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.67it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.85 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.67it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.86 seconds
# Total time: 10.76 seconds
# Enter LCM mode.
# [Fooocus] Downloading LCM components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] CFG = 1.0
# [Parameters] Seed = 8142620434772747284
# [Fooocus] Downloading upscale models ...
# [Inpaint] Parameterized inpaint is disabled.
# [Parameters] Sampler = lcm - lcm
# [Parameters] Steps = 8 - 8
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] detailed girl face, full color, cinematic light, dynamic background, elegant, intricate, highly detailed, rich deep colors, winning grand ambient, sharp focus, inspired very fine delicate, complex, innocent, stunning, creative, beautiful, symmetry, illuminated glowing, iconic, best, clear, perfect, futuristic, colorful, vivid, coherent, pretty, extremely aesthetic, romantic
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] detailed girl face, cinematic, highly detailed, sharp focus, elegant, intricate, epic composition, joyful, magical atmosphere, radiant light, vivid colors, pretty background, dynamic, ambient, professional, full detail, rich, striking, illuminated, perfect, symmetry, great, artistic, fine, awesome, inspiring, creative, pure, color, best, dramatic, beautiful
# [Fooocus] Preparing Fooocus text #3 ...
# [Prompt Expansion] detailed girl face, perfect, pretty, fine, solid background color, inspired, designed, vivid, beautiful, expressive, intricate, creative, detailed, amazing, symmetry, illuminated, colorful, light colors, attractive, advanced, cinematic, composition, elegant, complex, highly coherent, sharp, focus, full, artistic, appealing, rich, surreal, iconic, epic
# [Fooocus] Preparing Fooocus text #4 ...
# [Prompt Expansion] detailed girl face, light, strong dramatic cinematic, highly detailed, sharp focus, elegant, intricate, innocent, fine detail, inspired very romantic, background full color, ambient dynamic, fancy, amazing, symmetry, perfect, pretty, inspiring, brilliant, thought, epic, complex, professional composition, iconic, best, gorgeous, creative, beautiful, cool, awesome, marvelous
# [Fooocus] Encoding positive #1 ...
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding positive #4 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (325, 325, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# [Fooocus] VAE encoding ...
# Final resolution is (896, 1152), latent is (1024, 1024).
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 128])
# Preparation time: 3.44 seconds
# Using lcm scheduler.
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# Requested to load SDXL
# Loading 1 new model
# unload clone 3
# [Fooocus Model Management] Moving model(s) has taken 0.38 seconds
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.03it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 2.36 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.04it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.98 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.07it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.97 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.29861149191856384, sigma_max = 1.667901873588562
# 100%|█████████████████████████████████████████████| 8/8 [00:01<00:00,  7.04it/s]
# Image generated with private log at: /workspace/DeFooocus/outputs/2024-07-26/log.html
# Generating and saving time: 1.98 seconds
# Total time: 11.77 seconds
